# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read Data

# %%
df = pd.read_csv('/content/Coffee Sales.csv')
df.head()
# Out:
#          date datetime cash_type                 card  money    coffee_name
# 0  01-03-2024  15:50.5      card  ANON-0000-0000-0001   38.7          Latte
# 1  01-03-2024  19:22.5      card  ANON-0000-0000-0002   38.7  Hot Chocolate
# 2  01-03-2024  20:18.1      card  ANON-0000-0000-0002   38.7  Hot Chocolate
# 3  01-03-2024  46:33.0      card  ANON-0000-0000-0003   28.9      Americano
# 4  01-03-2024  48:14.6      card  ANON-0000-0000-0004   38.7          Latte

# %% [markdown]
# Data Exploration

# %%
df.shape
# Out:
# (1313, 6)

# %%
df.describe()
# Out:
#              money
# count  1313.000000
# mean     32.465788
# std       5.227782
# min      18.120000
# 25%      27.920000
# 50%      32.820000
# 75%      37.720000
# max      40.000000

# %%
df.head()
# Out:
#          date datetime cash_type                 card  money    coffee_name
# 0  01-03-2024  15:50.5      card  ANON-0000-0000-0001   38.7          Latte
# 1  01-03-2024  19:22.5      card  ANON-0000-0000-0002   38.7  Hot Chocolate
# 2  01-03-2024  20:18.1      card  ANON-0000-0000-0002   38.7  Hot Chocolate
# 3  01-03-2024  46:33.0      card  ANON-0000-0000-0003   28.9      Americano
# 4  01-03-2024  48:14.6      card  ANON-0000-0000-0004   38.7          Latte

# %%
df.columns
# Out:
# Index(['date', 'datetime', 'cash_type', 'card', 'money', 'coffee_name'], dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of             date datetime cash_type                 card  money  \
# 0     01-03-2024  15:50.5      card  ANON-0000-0000-0001  38.70
# 1     01-03-2024  19:22.5      card  ANON-0000-0000-0002  38.70
# 2     01-03-2024  20:18.1      card  ANON-0000-0000-0002  38.70
# 3     01-03-2024  46:33.0      card  ANON-0000-0000-0003  28.90
# 4     01-03-2024  48:14.6      card  ANON-0000-0000-0004  38.70
# ...          ...      ...       ...                  ...    ...
# 1308  17-08-2024  31:54.8      card  ANON-0000-0000-0277  23.02
# 1309  17-08-2024  33:49.0      card  ANON-0000-0000-0192  32.82
# 1310  17-08-2024  48:58.9      card  ANON-0000-0000-0456  32.82
# 1311  17-08-2024  18:56.8      card  ANON-0000-0000-0040  27.92
# 1312  17-08-2024  42:39.4      card  ANON-0000-0000-0519  32.82
#
#               coffee_name
# 0                   Latte
# 1           Hot Chocolate
# 2           Hot Chocolate
# 3               Americano
# 4                   Latte
# ...

# %%
df.isnull().sum()
# Out:
# date            0
# datetime        0
# cash_type       0
# card           80
# money           0
# coffee_name     0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 80

# %%
df.nunique()
# Out:
# date            167
# datetime       1289
# cash_type         2
# card            519
# money            16
# coffee_name       8
# dtype: int64

# %%
df['coffee_name'].unique()
# Out:
# array(['Latte', 'Hot Chocolate', 'Americano', 'Americano with Milk',
#        'Cocoa', 'Cortado', 'Espresso', 'Cappuccino'], dtype=object)

# %% [markdown]
# Visualization

# %%
sns.histplot(df['money'])
# Out:
# <Axes: xlabel='money', ylabel='Count'>

# %%
df['coffee_name'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Coffe Café')
plt.ylabel('')
plt.show()

# %%
sns.histplot(df['coffee_name'])
# Out:
# <Axes: xlabel='coffee_name', ylabel='Count'>

# %%
sns.histplot(df['cash_type'])
# Out:
# <Axes: xlabel='cash_type', ylabel='Count'>

# %%
import cv2
from matplotlib import pyplot as plt

# Load the image using cv2
img = cv2.imread('/content/IMAGE .jpg1.jpeg')

# Convert BGR to RGB format for proper display with matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (-0.5, 224.5, 224.5, -0.5)

# %% [markdown]
# Interpretation

# %% [markdown]
#                                    **Coffe Sales** **Data**
#
#                            1.Coffee sales data i have taken.
#                            2.After i have do some analysis about this data.
#   ## This is First Analysis
# **1.Import Libraries** :
#
#
# * First we can import libraries in coolab new notebook.
#
#   ##This is second Analysis
#
# **2.Read data** :
#
#            *  With in this we have some functions.
#
#               1.df.head()
#
#                   *   It means read csv file.
#
#                   *   It can explain general output and structure look like how to analyze it.
#
#
#   ## This is Third Analysis
#
#  ** 3.Data Exploration** :
#
#                   1.df.shape
#                   2.df.describe
#                   3.df.columns
#                   4.df.info
#                   5.df.isnull().sum()
#                   6.df.isnull().sum().sum()
#                   7.df.nunique()
#                   8.df['coffee_name'].unique()
#
#           In the above some functions we can use this data exploration analysis.
#
#  ## This Fourth Analysis
#
# ** 4.Visualization**:
#
#           1.sns.histplot(df['money']):
#
#                    * 'xlabel='money'- the horizontal axis represents some form of monetary value.
#
#                    * 'ylabel='Count'- the vertical axis represents a count or frequency of occurrences.
#
#            2.Pie chart:
#
#                    *  The pie chart visually represents the proportion of each coffee type (coffee_name) in your dataset.
#
#                    *  Each slice is labeled with a percentage, showing how much of the total each coffee type accounts for. For example, if one type of coffee makes up 34% of the total, it will be labeled as "34.0%".
#
#
#             3.sns.histplot(df['coffee_name']):
#
#                     * This likely represents different categories of cash types
#                       in your dataset
#
#                     * This represents the frequency or count of each cash_type
#                       in your dataset.
#
#             4.Image related to coffee sales:
#
#                      This is all analysis process of coffee sales data sets.
